# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset= pd.read_csv("study_hours.csv")
dataset.head()
# Out:
#    Hours  Marks
# 0      5     30
# 1      8     32
# 2     10     35
# 3     12     37
# 4     15     40

# %%
x = dataset.iloc[:,:-1]
y = dataset.iloc[:,1]
x.head()
# Out:
#    Hours
# 0      5
# 1      8
# 2     10
# 3     12
# 4     15

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# 25.540193561129783
# [0.97649615]

# %%
y_pred = regressor.predict(x_test)
df = pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
from sklearn.metrics import r2_score
a=r2_score(y_test, y_pred)

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred)) 
print('Mean_sqaured_error:',metrics.mean_squared_error(y_test, y_pred))
print('Root_Mean_squared_error:',np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.5941141615642866
# Mean_sqaured_error: 0.6442809441643589
# Root_Mean_squared_error: 0.8026711307654953

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,regressor.predict(x_train))
plt.xlabel("Hours studied")
plt.ylabel("Marks")
plt.title("Simple Linear Regression")
plt.show()

# %%
import joblib
joblib.dump(regressor,"marks_model.pkl")
# Out:
# ['marks_model.pkl']
